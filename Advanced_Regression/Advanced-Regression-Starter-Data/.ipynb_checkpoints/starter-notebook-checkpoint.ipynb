# %% [markdown]
# # Regression Predict Student Solution
#
# © Explore Data Science Academy
#
# ---
# ### Honour Code
#
# I {**YOUR NAME, YOUR SURNAME**}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the [EDSA honour code](https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.
#
# ### Predict Overview: Spain Electricity Shortfall Challenge
#
# The government of Spain is considering an expansion of it's renewable energy resource infrastructure investments. As such, they require information on the trends and patterns of the countries renewable sources and fossil fuel energy generation. Your company has been awarded the contract to:
#
# - 1. analyse the supplied data;
# - 2. identify potential errors in the data and clean the existing data set;
# - 3. determine if additional features can be added to enrich the data set;
# - 4. build a model that is capable of forecasting the three hourly demand shortfalls;
# - 5. evaluate the accuracy of the best machine learning model;
# - 6. determine what features were most important in the model’s prediction decision, and
# - 7. explain the inner working of the model to a non-technical audience.
#
# Formally the problem statement was given to you, the senior data scientist, by your manager via email reads as follow:
#
# > In this project you are tasked to model the shortfall between the energy generated by means of fossil fuels and various renewable sources - for the country of Spain. The daily shortfall, which will be referred to as the target variable, will be modelled as a function of various city-specific weather features such as `pressure`, `wind speed`, `humidity`, etc. As with all data science projects, the provided features are rarely adequate predictors of the target variable. As such, you are required to perform feature engineering to ensure that you will be able to accurately model Spain's three hourly shortfalls.
#
# On top of this, she has provided you with a starter notebook containing vague explanations of what the main outcomes are.

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Loading Data</a>
#
# <a href=#three>3. Exploratory Data Analysis (EDA)</a>
#
# <a href=#four>4. Data Engineering</a>
#
# <a href=#five>5. Modeling</a>
#
# <a href=#six>6. Model Performance</a>
#
# <a href=#seven>7. Model Explanations</a>

# %% [markdown]
#  <a id="one"></a>
# ## 1. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Importing Packages ⚡ |
# | :--------------------------- |
# | In this section you are required to import, and briefly discuss, the libraries that will be used throughout your analysis and modelling. |
#
# ---

# %%
# Libraries for data loading, data manipulation and data visulisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# Libraries for data preparation and model building
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as sm
from statsmodels.graphics.correlation import plot_corr
import pickle

# Setting global constants to ensure notebook results are reproducible
PARAMETER_CONSTANT = '###'

# %% [markdown]
# <a id="two"></a>
# ## 2. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
# | In this section you are required to load the data from the `df_train` file into a DataFrame. |
#
# ---

# %%
df_train = pd.read_csv('df_train.csv')

# %% [markdown]
# <a id="three"></a>
# ## 3. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
# | In this section, you are required to perform an in-depth analysis of all the variables in the DataFrame. |
#
# ---

# %%
# look at data statistics
df_train.shape
# Out:
# (8763, 49)

# %%
df_train.head(3)
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
#
#    Bilbao_clouds_all  Bilbao_wind_speed  ...  Madrid_temp_max  Barcelona_temp  \
# 0                0.0                1.0  ...       265.938000      281.013000
# 1                0.0                1.0  ...       266.386667      280.561667
# 2                0.0                1.0  ...       272.708667      281.583667
#
# ...

# %%
df_train.describe()
# Out:
#         Unnamed: 0  Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# count  8763.000000        8763.000000     8763.000000          8763.000000
# mean   4381.000000           2.425729        0.135753             2.586272
# std    2529.804538           1.850371        0.374901             2.411190
# min       0.000000           0.000000        0.000000             0.000000
# 25%    2190.500000           1.000000        0.000000             1.000000
# 50%    4381.000000           2.000000        0.000000             1.666667
# 75%    6571.500000           3.333333        0.100000             3.666667
# max    8762.000000          13.000000        3.000000            52.000000
#
#        Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# count       8763.000000      8763.000000        8763.000000
# mean          62.658793        57.414717          43.469132
# std           22.621226        24.335396          32.551044
# ...

# %%
df_train.isnull().sum().sort_values(ascending=False)
# Out:
# Valencia_pressure       2068
# Unnamed: 0                 0
# Madrid_weather_id          0
# Bilbao_pressure            0
# Seville_weather_id         0
# Seville_temp_max           0
# Madrid_pressure            0
# Valencia_temp_max          0
# Valencia_temp              0
# Bilbao_weather_id          0
# Seville_temp               0
# Valencia_humidity          0
# Valencia_temp_min          0
# Barcelona_temp_max         0
# Madrid_temp_max            0
# Barcelona_temp             0
# Bilbao_temp_min            0
# Bilbao_temp                0
# Barcelona_temp_min         0
# Bilbao_temp_max            0
# Seville_temp_min           0
# Madrid_temp                0
# Madrid_temp_min            0
# Barcelona_weather_id       0
# Valencia_snow_3h           0
# time                       0
# Barcelona_rain_3h          0
# Madrid_wind_speed          0
# Valencia_wind_deg          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# ...

# %%
df_train.Valencia_pressure.describe()
# Out:
# count    6695.000000
# mean     1012.051407
# std         9.506214
# min       972.666667
# 25%      1010.333333
# 50%      1015.000000
# 75%      1018.000000
# max      1021.666667
# Name: Valencia_pressure, dtype: float64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8763 non-null   int64
#  1   time                  8763 non-null   object
#  2   Madrid_wind_speed     8763 non-null   float64
#  3   Valencia_wind_deg     8763 non-null   object
#  4   Bilbao_rain_1h        8763 non-null   float64
#  5   Valencia_wind_speed   8763 non-null   float64
#  6   Seville_humidity      8763 non-null   float64
#  7   Madrid_humidity       8763 non-null   float64
#  8   Bilbao_clouds_all     8763 non-null   float64
#  9   Bilbao_wind_speed     8763 non-null   float64
#  10  Seville_clouds_all    8763 non-null   float64
#  11  Bilbao_wind_deg       8763 non-null   float64
#  12  Barcelona_wind_speed  8763 non-null   float64
#  13  Barcelona_wind_deg    8763 non-null   float64
# ...

# %%
#Convert time from object to datetime
df_train['time'] = pd.to_datetime(df_train['time'])

#Convert valencia wind degree and Seville pressure to int from object
# Label Encoding
labelencoder = LabelEncoder()
df_train['Valencia_wind_deg'] = labelencoder.fit_transform(df_train['Valencia_wind_deg'])
df_train['Seville_pressure'] = labelencoder.fit_transform(df_train['Seville_pressure'])

# %%
df_train.columns
# Out:
# Index(['Unnamed: 0', 'time', 'Madrid_wind_speed', 'Valencia_wind_deg',
#        'Bilbao_rain_1h', 'Valencia_wind_speed', 'Seville_humidity',
#        'Madrid_humidity', 'Bilbao_clouds_all', 'Bilbao_wind_speed',
#        'Seville_clouds_all', 'Bilbao_wind_deg', 'Barcelona_wind_speed',
#        'Barcelona_wind_deg', 'Madrid_clouds_all', 'Seville_wind_speed',
#        'Barcelona_rain_1h', 'Seville_pressure', 'Seville_rain_1h',
#        'Bilbao_snow_3h', 'Barcelona_pressure', 'Seville_rain_3h',
#        'Madrid_rain_1h', 'Barcelona_rain_3h', 'Valencia_snow_3h',
#        'Madrid_weather_id', 'Barcelona_weather_id', 'Bilbao_pressure',
#        'Seville_weather_id', 'Valencia_pressure', 'Seville_temp_max',
#        'Madrid_pressure', 'Valencia_temp_max', 'Valencia_temp',
#        'Bilbao_weather_id', 'Seville_temp', 'Valencia_humidity',
#        'Valencia_temp_min', 'Barcelona_temp_max', 'Madrid_temp_max',
#        'Barcelona_temp', 'Bilbao_temp_min', 'Bilbao_temp',
# ...

# %%
train_df = df_train[['Valencia_temp_min', 'Barcelona_temp_max', 'Madrid_temp_max',
                     'Barcelona_temp', 'Bilbao_temp_min', 'Bilbao_temp',
                     'Barcelona_temp_min', 'Bilbao_temp_max', 'Seville_temp_min',
                     'Madrid_temp', 'Madrid_temp_min']]

# %%
#Temperature feature interactions
heatmap = sns.heatmap(train_df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
# Create the average for all cities to reflect Spain as a whole

df_train['Average_Speed'] = (df_train.Madrid_wind_speed+df_train.Valencia_wind_speed +df_train.Barcelona_wind_speed+df_train.Bilbao_wind_speed+df_train.Seville_wind_speed)/5
df_train['Average_wind_deg'] = (df_train.Valencia_wind_deg +df_train.Bilbao_wind_deg+df_train.Barcelona_wind_deg)/3
df_train['Average_rain_1h'] = (df_train.Bilbao_rain_1h + df_train. Barcelona_rain_1h +df_train. Seville_rain_1h + df_train.Madrid_rain_1h)/4
df_train['Average_rain_3h'] = (df_train.Seville_rain_3h +df_train.Barcelona_rain_3h)/2
df_train['Average_snow_3h'] = (df_train.Bilbao_snow_3h +df_train. Valencia_snow_3h)/2
df_train['Average_humidity'] = (df_train.Seville_humidity  +df_train.Madrid_humidity+df_train.Valencia_humidity)/3
df_train['Average_clouds_all'] = (df_train.Bilbao_clouds_all+df_train.Seville_clouds_all  +df_train.Madrid_clouds_all)/3
df_train['Average_pressure'] = (df_train.Seville_pressure+df_train.Barcelona_pressure+df_train.Bilbao_pressure+ df_train.Valencia_pressure + df_train. Madrid_pressure)/5
df_train['Average_temp_max'] = (df_train.Seville_temp_max + df_train.Valencia_temp_max +df_train.Barcelona_temp_max +df_train.Madrid_temp_max +df_train.Bilbao_temp_max )/5
df_train['Average_temp_min'] = (df_train.Valencia_temp_min +df_train.Bilbao_temp_min  +df_train.Barcelona_temp_min+df_train.Seville_temp_min+df_train. Madrid_temp_min)/5
df_train['Average_temp'] = (df_train.Seville_temp +df_train.Valencia_temp +df_train.Barcelona_temp +df_train.Bilbao_temp+df_train. Madrid_temp)/5

# %%
# Extracting time and the Average for all cities
df_average_time = df_train[['time','Average_Speed','Average_wind_deg','Average_rain_1h',
                         'Average_rain_3h','Average_snow_3h','Average_humidity','Average_clouds_all',
                         'Average_pressure','Average_temp_max','Average_temp_min','Average_temp']]
df_average_time
# Out:
#                     time  Average_Speed  Average_wind_deg  Average_rain_1h  \
# 0    2015-01-01 03:00:00       2.400000         90.333333            0.000
# 1    2015-01-01 06:00:00       2.066667        120.333333            0.000
# 2    2015-01-01 09:00:00       1.533333        183.111111            0.000
# 3    2015-01-01 12:00:00       1.866667        160.222222            0.000
# 4    2015-01-01 15:00:00       1.933333        150.666667            0.000
# ...                  ...            ...               ...              ...
# 8758 2017-12-31 09:00:00       2.133333        105.444444            0.000
# 8759 2017-12-31 12:00:00       3.933333        146.444444            0.000
# 8760 2017-12-31 15:00:00       6.200000        183.000000            0.125
# 8761 2017-12-31 18:00:00       5.400000        159.333333            0.125
# 8762 2017-12-31 21:00:00       3.800000        139.666667            0.000
#
# ...

# %%
temperature = ['Madrid_temp_max', 'Bilbao_temp_max', 'Barcelona_temp_max', 'Seville_temp_max', 'Valencia_temp_max', 'Madrid_temp_min', 'Valencia_temp_min', 'Bilbao_temp_min', 'Barcelona_temp_min']

# Filter out non-numeric values in 'load_shortfall_3h'
numeric_load_shortfall = pd.to_numeric(df_train['load_shortfall_3h'], errors='coerce')

# Correlations between 'load shortfall_3h' and temperature variables
correlations = df_train[temperature].apply(lambda col: numeric_load_shortfall.corr(col))

# Bar plot to visualize the correlations
plt.figure(figsize=(10, 6))
correlations.plot(kind='bar', color='blue')
plt.xlabel('Temperature Variable')
plt.ylabel('Correlation with Load Shortfall')
plt.title('Correlation of Temperature Variables with Load Shortfall')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# have a look at feature distributions

df_train.hist(figsize = (25, 25));

# %%
# Plot the load shortfall against time
plt.plot(df_train['time'], df_train['load_shortfall_3h'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
print(df_train['time'].min())
print(df_train['time'].max())
# Out:
# 2015-01-01 03:00:00
# 2017-12-31 21:00:00

# %%
#yearly time series data
monthly_shortfall = pd.DataFrame(df_train[df_train['time'] <'2015-01-31'])

# %%
# Plot the load shortfall against time
plt.plot(monthly_shortfall['time'], monthly_shortfall['load_shortfall_3h'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
#Target scatter
##Kamo  plot scatter splot between features and the Target Variable.

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data engineering ⚡ |
# | :--------------------------- |
# | In this section you are required to: clean the dataset, and possibly create new features - as identified in the EDA phase. |
#
# ---

# %%
# remove missing values/ features

#drop similar features
focus_features = ['Barcelona_wind_speed','Madrid_temp_min','day_of_week','Barcelona_rain_1h']

# %%
import pandas as pd

# Assuming df_test is loaded or created
df_test = pd.read_csv('df_test.csv')  # Replace 'df_test.csv' with the actual file path or loading logic

# Now you can use df_test along with df_train
df_train['time'] = pd.to_datetime(df_train['time'])
df_test['time'] = pd.to_datetime(df_test['time'])

df_train['day_of_week'] = df_train['time'].dt.day_name()
df_test['day_of_week'] = df_test['time'].dt.day_name()

day_Dic = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6,
    'Sunday': 7
}

def day_num(df, day_dic):
    day_number = []
    for day in df['day_of_week']:
        day_number.append(int(day_dic[day]))
    return day_number

train_day_num = day_num(df_train, day_Dic)
test_day_num = day_num(df_test, day_Dic)

# %%
df_train['Day_Num'] = train_day_num
df_test['Day_Num'] = test_day_num

# %%
# engineer existing features
from sklearn.linear_model import Lasso
import pandas as pd

# Assuming df_train is your original DataFrame
# Adjust 'load_shortfall_3h' to your target variable
target_column = 'load_shortfall_3h'

# Drop non-numeric columns and convert 'time' to numeric
numeric_columns = df_train.select_dtypes(include=['number']).columns
X = df_train[numeric_columns].drop(target_column, axis=1)
X['time'] = pd.to_numeric(df_train['time'], errors='coerce')

# Encode 'day_of_week' into numerical representations
day_of_week_mapping = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6,
    'Sunday': 7
}
X['day_of_week'] = df_train['day_of_week'].map(day_of_week_mapping)

# Drop rows with NaN values, as Lasso doesn't handle them
X = X.dropna()

# Now, make sure 'y' only contains rows that are present in 'X'
y = df_train.loc[X.index, target_column]

# Define the Lasso regression model
lasso_model = Lasso(alpha=1.0, random_state=42)

# Fit the model
lasso_model.fit(X, y)

# Get feature coefficients
feature_coefficients = pd.Series(lasso_model.coef_, index=X.columns)

# Print or use feature coefficients as needed
print(feature_coefficients)
# Out:
# Unnamed: 0             4.446356e-01
# Madrid_wind_speed     -2.289933e+02
# Valencia_wind_deg     -4.489499e+01
# Bilbao_rain_1h        -2.595538e+02
# Valencia_wind_speed   -1.286027e+02
#                            ...
# Average_temp_min       1.829136e+02
# Average_temp          -2.465716e+01
# Day_Num               -3.865908e+02
# time                  -2.277941e-14
# day_of_week           -2.296507e+00
# Length: 61, dtype: float64
# C:\Users\Katlego\anaconda3\envs\notebook-6.4.12\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.491e+10, tolerance: 1.863e+07
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# <a id="five"></a>
# ## 5. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Modelling ⚡ |
# | :--------------------------- |
# | In this section, you are required to create one or more regression models that are able to accurately predict the thee hour load shortfall. |
#
# ---

# %%
# Load libraries and data
import pandas as pd
from sklearn.model_selection import train_test_split

# Load your data
# Assuming you have already loaded 'df_train' and 'df_test'

# Split data
X_train, X_test, y_train, y_test = train_test_split(df_train, df_train['load_shortfall_3h'], test_size=0.2, random_state=50)

# Check column names
print(X_train.columns)
print(y_train.name)

# Reset index if needed
X_train.reset_index(inplace=True, drop=True)
y_train.reset_index(inplace=True, drop=True)

# Check again
print(X_train.columns)
print(y_train.name)
# Out:
# Index(['Unnamed: 0', 'time', 'Madrid_wind_speed', 'Valencia_wind_deg',
#        'Bilbao_rain_1h', 'Valencia_wind_speed', 'Seville_humidity',
#        'Madrid_humidity', 'Bilbao_clouds_all', 'Bilbao_wind_speed',
#        'Seville_clouds_all', 'Bilbao_wind_deg', 'Barcelona_wind_speed',
#        'Barcelona_wind_deg', 'Madrid_clouds_all', 'Seville_wind_speed',
#        'Barcelona_rain_1h', 'Seville_pressure', 'Seville_rain_1h',
#        'Bilbao_snow_3h', 'Barcelona_pressure', 'Seville_rain_3h',
#        'Madrid_rain_1h', 'Barcelona_rain_3h', 'Valencia_snow_3h',
#        'Madrid_weather_id', 'Barcelona_weather_id', 'Bilbao_pressure',
#        'Seville_weather_id', 'Valencia_pressure', 'Seville_temp_max',
#        'Madrid_pressure', 'Valencia_temp_max', 'Valencia_temp',
#        'Bilbao_weather_id', 'Seville_temp', 'Valencia_humidity',
#        'Valencia_temp_min', 'Barcelona_temp_max', 'Madrid_temp_max',
#        'Barcelona_temp', 'Bilbao_temp_min', 'Bilbao_temp',
# ...

# %%
features = df_train.drop(columns=['load_shortfall_3h'])
target = df_train['load_shortfall_3h']

# %%
# Define your formula string
formula_str = 'load_shortfall_3h ~ ' + ' + '.join([col for col in features.columns if col != 'Unnamed: 0'])

# %% [markdown]
# <a id="six"></a>
# ## 6. Model Performance
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model performance ⚡ |
# | :--------------------------- |
# | In this section you are required to compare the relative performance of the various trained ML models on a holdout dataset and comment on what model is the best and why. |
#
# ---

# %%
# Remove extra columns in X_test_processed
X_test_processed = X_test_processed[X_train_processed.columns]

# %%
#model performance summary from Stats Models

# %%
# my_comment_adding predictions
test_cols = df_test[selected_cols[:-1]]
load_predictions = fitted.predict(test_cols)

# %%
#save predictions
predictions = list(load_predictions)
csv_dict  = {
    'time': list(df_test['time']),
    'load_shortfall_3h': predictions
}

(pd.DataFrame.from_dict(data=csv_dict, orient='index').to_csv('predictions_v4.csv', header=False))

# %%
# Choose best model and motivate why it is the best choice
# Out:
# (2920, 48)

# %% [markdown]
# <a id="seven"></a>
# ## 7. Model Explanations
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, you are required to discuss how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |
#
# ---

# %%
# discuss chosen methods logic
